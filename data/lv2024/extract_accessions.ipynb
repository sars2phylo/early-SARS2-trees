# %% [markdown]
# # Extract accessions from supplementary table 3

# %%
import pandas as pd

dfs = pd.read_excel("Supplementary Tables 1-3.xlsx", skiprows=1, sheet_name=None)

before_date = pd.to_datetime("2020-03-01")

# %%
table_s3 = (
    dfs["Supplementary Table 3"]
    .rename(
        columns={
            "Accession ID": "accession",
            "Strain name": "strain",
            "Lineage": "lineage",
            "Collection date": "date",
        }
    )
    [["accession", "strain", "lineage", "date"]]
    .assign(date=lambda x: pd.to_datetime(x["date"]))
    .query("date < @before_date")
)

table_s3
# Out:
#             accession                              strain lineage       date
# 0      EPI_ISL_402123            Wuhan/IPBCAMS-WH-01/2019       B 2019-12-24
# 1      EPI_ISL_406798                     Wuhan/WH01/2019       B 2019-12-26
# 2          MN908947.3              Wuhan-Hu-1-/2019-12-26       B 2019-12-26
# 3      EPI_ISL_529217                 Wuhan/IME-WH05/2019       B 2019-12-30
# 4      EPI_ISL_529216                 Wuhan/IME-WH04/2019       B 2019-12-30
# ...               ...                                 ...     ...        ...
# 1742   EPI_ISL_413022  Switzerland/ZH-UZH-1000477796/2020     B.1 2020-02-29
# 1743   EPI_ISL_413021  Switzerland/ZH-UZH-1000477757/2020     B.1 2020-02-29
# 1744  EPI_ISL_1064059              Italy/VEN-SR-72-B/2020       B 2020-02-29
# 1745  EPI_ISL_1015045             France/IDF_PSL_141/2020     B.1 2020-02-29
# 1746  EPI_ISL_1015034             France/IDF_PSL_137/2020     B.1 2020-02-29
#
# [1747 rows x 4 columns]

# %%
annotations = pd.read_csv("jointWHO_sequences.csv")

annotations
# Out:
#    joint_WHO_China_sample_id                            strain  \
# 0                        S01  hCoV-19/Wuhan/IPBCAMS-WH-05/2020
# 1                        S02  hCoV-19/Wuhan/IPBCAMS-WH-01/2019
# 2                        S03           hCoV-19/Wuhan/WH01/2019
# 3                        S04          hCoV-19/Wuhan/WIV02/2019
# 4                        S04       hCoV-19/Wuhan/IME-WH02/2019
# 5                        S04    hCoV-19/Wuhan/HBCDC-HB-02/2019
# 6                        S04   hCoV-19/Wuhan/IVDC-HB-GX02/2019
# 7                        S05  hCoV-19/Wuhan/IPBCAMS-WH-04/2019
# 8                        S05     hCoV-19/Wuhan/IVDC-HB-04/2020
# 9                        S06                        Wuhan-Hu-1
# 10                       S07          hCoV-19/Wuhan/WHU01/2020
# 11                       S08       hCoV-19/Wuhan/IME-WH04/2019
# 12                       S08          hCoV-19/Wuhan/WIV07/2019
# 13                       S09           hCoV-19/Wuhan/WH03/2020
# 14                       S09          hCoV-19/Wuhan/WHU02/2020
# 15                       S10    hCoV-19/Wuhan/HBCDC-HB-03/2019
# 16                       S10  hCoV-19/Wuhan/IPBCAMS-WH-02/2019
# 17                       S10          hCoV-19/Wuhan/WIV04/2019
# 18                       S10    hCoV-19/Wuhan/HBCDC-HB-01/2019
# 19                       S11  hCoV-19/Wuhan/IPBCAMS-WH-03/2019
# 20                       S11          hCoV-19/Wuhan/WIV05/2019
# 21                       S12          hCoV-19/Wuhan/WIV06/2019
# 22                       S12       hCoV-19/Wuhan/IME-WH03/2019
# 23                       S13       hCoV-19/Wuhan/IME-WH01/2019
#
#          accession  from_market         addtl_annotations
# 0   EPI_ISL_403928         True      2019 market sequence
# 1   EPI_ISL_402123         True      2019 market sequence
# 2   EPI_ISL_406798         True      2019 market sequence
# 3   EPI_ISL_402127         True      2019 market sequence
# 4   EPI_ISL_529214         True      2019 market sequence
# 5   EPI_ISL_412898         True      2019 market sequence
# 6   EPI_ISL_434534         True      2019 market sequence
# 7   EPI_ISL_403929         True      2019 market sequence
# 8   EPI_ISL_402120         True      2019 market sequence
# 9       MN908947.3         True      2019 market sequence
# 10  EPI_ISL_406716         True      2019 market sequence
# 11  EPI_ISL_529216         True      2019 market sequence
# 12  EPI_ISL_402130         True      2019 market sequence
# 13  EPI_ISL_406800         True      2019 market sequence
# 14  EPI_ISL_406717         True      2019 market sequence
# 15  EPI_ISL_412899         True      2019 market sequence
# 16  EPI_ISL_403931         True      2019 market sequence
# 17  EPI_ISL_402124         True      2019 market sequence
# 18  EPI_ISL_402132         True      2019 market sequence
# 19  EPI_ISL_403930         True      2019 market sequence
# 20  EPI_ISL_402128         True      2019 market sequence
# 21  EPI_ISL_402129         True      2019 market sequence
# 22  EPI_ISL_529215         True      2019 market sequence
# 23  EPI_ISL_529213        False  2019 non-market sequence

# %%
merged = table_s3.merge(
    annotations[["accession", "joint_WHO_China_sample_id", "addtl_annotations"]],
    on="accession",
    how="left",
    validate="one_to_one",
).assign(addtl_annotations=lambda x: x["addtl_annotations"].fillna("other"))

# %%
merged.to_csv("all_accessions.csv", index=False)

with open("gisaid_accessions.csv", "w") as f:
    f.write(
        ", ".join(merged.query("accession.str.startswith('EPI_')")["accession"].tolist())
    )
    
with open("genbank_accessions.csv", "w") as f:
    f.write(
        ", ".join(merged.query("not accession.str.startswith('EPI_')")["accession"].tolist())
    )
